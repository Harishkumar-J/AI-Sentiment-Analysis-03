# %%
import pandas as ps
import regex as re
import numpy as np

from vaderSentiment.vaderSentiment import SentimentIntensityAnalysis

import transformers
from transformers import pipeline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 5
#       2 import regex as re
#       3 import numpy as np
# ----> 5 from vaderSentiment.vaderSentiment import SentimentIntensityAnalysis
#       7 import transformers
#       8 from transformers import pipeline
#
# ImportError: cannot import name 'SentimentIntensityAnalysis' from 'vaderSentiment.vaderSentiment' (C:\Users\sanka\anaconda3\envs\nlp_course_env\Lib\site-packages\vaderSentiment\vaderSentiment.py)
